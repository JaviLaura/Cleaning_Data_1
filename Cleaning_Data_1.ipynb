# %% [markdown]
# <a href="https://colab.research.google.com/github/JaviLaura/Cleaning_Data_1/blob/main/Cleaning_Data_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

choleraDF = pd.read_csv("https://static.junilearning.com/python_data_science/cholera.csv")
display(choleraDF)
# Out:
#                  Country  Year Number of reported cases of cholera  \
# 0            Afghanistan  2016                                 677
# 1            Afghanistan  2015                               58064
# 2            Afghanistan  2014                               45481
# 3            Afghanistan  2013                                3957
# 4            Afghanistan  2012                                  12
# ...                  ...   ...                                 ...
# 2487  Russian Federation  1980                                 NaN
# 2488  Russian Federation  1971                                 NaN
# 2489              Sweden  1984                                 NaN
# 2490         Switzerland  1980                                 NaN
# 2491            Cambodia  2011                                 NaN
#
#      Number of reported deaths from cholera Cholera case fatality rate  \
# 0                                         5                        0.7
# ...

# %%
choleraDF.count()
# Out:
# Country                                   2492
# Year                                      2492
# Number of reported cases of cholera       2470
# Number of reported deaths from cholera    2375
# Cholera case fatality rate                2365
# WHO Region                                2492
# dtype: int64

# %%
choleraDF.isnull().sum()
# Out:
# Country                                     0
# Year                                        0
# Number of reported cases of cholera        22
# Number of reported deaths from cholera    117
# Cholera case fatality rate                127
# WHO Region                                  0
# dtype: int64

# %%
choleraDFclean = choleraDF.dropna().copy()
display(choleraDFclean)
# Out:
#           Country  Year Number of reported cases of cholera  \
# 0     Afghanistan  2016                                 677
# 1     Afghanistan  2015                               58064
# 2     Afghanistan  2014                               45481
# 3     Afghanistan  2013                                3957
# 4     Afghanistan  2012                                  12
# ...           ...   ...                                 ...
# 2463     Zimbabwe  1992                                2048
# 2465     Zimbabwe  1985                                 144
# 2466     Zimbabwe  1976                                 144
# 2467     Zimbabwe  1975                                 615
# 2468     Zimbabwe  1974                                  37
#
#      Number of reported deaths from cholera Cholera case fatality rate  \
# 0                                         5                        0.7
# 1                                         8                       0.01
# ...

# %%
choleraDFclean.count()
# Out:
# Country                                   2354
# Year                                      2354
# Number of reported cases of cholera       2354
# Number of reported deaths from cholera    2354
# Cholera case fatality rate                2354
# WHO Region                                2354
# dtype: int64

# %%
choleraDFclean.isnull().sum()
# Out:
# Country                                   0
# Year                                      0
# Number of reported cases of cholera       0
# Number of reported deaths from cholera    0
# Cholera case fatality rate                0
# WHO Region                                0
# dtype: int64

# %%
choleraDFclean.describe()
# Out:
#               Year
# count  2354.000000
# mean   1992.390399
# std      14.836268
# min    1949.000000
# 25%    1981.000000
# 50%    1994.000000
# 75%    2005.000000
# max    2016.000000

# %%
choleraDFclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2354 entries, 0 to 2468
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 2354 non-null   object
#  1   Year                                    2354 non-null   int64
#  2   Number of reported cases of cholera     2354 non-null   object
#  3   Number of reported deaths from cholera  2354 non-null   object
#  4   Cholera case fatality rate              2354 non-null   object
#  5   WHO Region                              2354 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 128.7+ KB

# %%
choleraDFclean["Number of reported cases of cholera"] = pd.to_numeric(choleraDFclean["Number of reported cases of cholera"], errors="coerce")
choleraDFclean["Number of reported deaths from cholera"] = pd.to_numeric(choleraDFclean["Number of reported deaths from cholera"], errors="coerce")
choleraDFclean["Cholera case fatality rate"] = pd.to_numeric(choleraDFclean["Cholera case fatality rate"], errors="coerce")

# %%
choleraDFclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2354 entries, 0 to 2468
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 2354 non-null   object
#  1   Year                                    2354 non-null   int64
#  2   Number of reported cases of cholera     2353 non-null   float64
#  3   Number of reported deaths from cholera  2352 non-null   float64
#  4   Cholera case fatality rate              2352 non-null   float64
#  5   WHO Region                              2354 non-null   object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 128.7+ KB

# %%
choleraDFclean = choleraDFclean.dropna()
display(choleraDFclean)
# Out:
#           Country  Year  Number of reported cases of cholera  \
# 0     Afghanistan  2016                                677.0
# 1     Afghanistan  2015                              58064.0
# 2     Afghanistan  2014                              45481.0
# 3     Afghanistan  2013                               3957.0
# 4     Afghanistan  2012                                 12.0
# ...           ...   ...                                  ...
# 2463     Zimbabwe  1992                               2048.0
# 2465     Zimbabwe  1985                                144.0
# 2466     Zimbabwe  1976                                144.0
# 2467     Zimbabwe  1975                                615.0
# 2468     Zimbabwe  1974                                 37.0
#
#       Number of reported deaths from cholera  Cholera case fatality rate  \
# 0                                        5.0                        0.70
# 1                                        8.0                        0.01
# ...

# %%
choleraDFclean.isnull().sum()
# Out:
# Country                                   0
# Year                                      0
# Number of reported cases of cholera       0
# Number of reported deaths from cholera    0
# Cholera case fatality rate                0
# WHO Region                                0
# dtype: int64

# %%
#Sort dataframes by column names
choleraDFclean.sort_values(by="Number of reported cases of cholera",ascending=False)
# Out:
#        Country  Year  Number of reported cases of cholera  \
# 897      Haiti  2011                             340311.0
# 1731      Peru  1991                             322562.0
# 1730      Peru  1992                             242237.0
# 971      India  1953                             213225.0
# 898      Haiti  2010                             179379.0
# ...        ...   ...                                  ...
# 2229   Ukraine  2007                                  0.0
# 2069     Sudan  1999                                  0.0
# 701   Ethiopia  2005                                  0.0
# 703   Ethiopia  1982                                  0.0
# 754     Gambia  2006                                  0.0
#
#       Number of reported deaths from cholera  Cholera case fatality rate  \
# 897                                   2869.0                        0.84
# 1731                                  2909.0                        0.90
# ...

# %%
choleraDFclean.describe()
# Out:
#               Year  Number of reported cases of cholera  \
# count  2352.000000                          2352.000000
# mean   1992.370323                          3850.832483
# std      14.826581                         15235.256736
# min    1949.000000                             0.000000
# 25%    1981.000000                            12.000000
# 50%    1994.000000                           270.000000
# 75%    2005.000000                          2004.750000
# max    2016.000000                        340311.000000
#
#        Number of reported deaths from cholera  Cholera case fatality rate
# count                             2352.000000                 2352.000000
# mean                               381.454507                    5.784957
# std                               3586.014473                   15.597901
# min                                  0.000000                    0.000000
# 25%                                  0.000000                    0.000000
# ...

# %%
#Scatterplot
sns.regplot(x = "Number of reported cases of cholera", y = "Number of reported deaths from cholera", data = choleraDFclean, line_kws={"color":"green"})
